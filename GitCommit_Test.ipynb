# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Github_Commit_Folder
# Out:
# /content/drive/MyDrive/Github_Commit_Folder

# %%
# %cd AI-School_DL
# Out:
# /content/drive/MyDrive/Github_Commit_Folder/AI-School_DL

# %%
# !git config --global user.email 'ko0413hee@gmail.com'
# !git config --global user.name 'gowonhee'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/Github_Commit_Folder/AI-School_DL
# Out:
# /content/drive/MyDrive/Github_Commit_Folder/AI-School_DL

# %%
# !git config --global user.email 'ko0413hee@gmail.com'
# !git config --global user.name 'gowonhee'

# %%
# !git add --all "GitCommit_Test.ipynb"
# Out:
# fatal: pathspec 'GitCommit_Test.ipynb' did not match any files

# %%
# !git commit -m 'first load'
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	"00.DeepLearning \341\204\206\341\205\241\341\206\272\341\204\207\341\205\251\341\204\200\341\205\265.ipynb\341\204\213\341\205\264 \341\204\211\341\205\241\341\204\207\341\205\251\341\206\253"
# 	"01.\341\204\213\341\205\265\341\204\214\341\205\265\341\206\253\341\204\207\341\205\256\341\206\253\341\204\205\341\205\262(\341\204\213\341\205\262\341\204\207\341\205\241\341\206\274\341\204\213\341\205\241\341\206\267 \341\204\203\341\205\246\341\204\213\341\205\265\341\204\220\341\205\245).ipynb\341\204\213\341\205\264 \341\204\211\341\205\241\341\204\207\341\205\251\341\206\253"
# ...
